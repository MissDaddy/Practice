# %%
import turtle as trl
from turtle import *

t1= trl.Turtle()
t1.color("black")
t1.setheading(60)
t1.setposition(0,0)

#create a random size range for the pen size!
#cycle through the different pen colors

t2= trl.Turtle()
t2.color("grey")
t2.setheading(120)
t2.setposition(0,0)
t2.onclick(t2.fillcolor("grey"))

t3= trl.Turtle()
t3.color("blue")
t3.setheading(180)
t3.setposition(0,0)

t4= trl.Turtle()
t4.color("purple")
t4.setheading(240)
t4.setposition(0,0)

t5= trl.Turtle()
t5.color("green")
t5.setheading(300)
t5.setposition(0,0)

t6 = trl.Turtle()
t6.color("red")
t6.setheading(0)
t6.setposition(0,0)


def hex1():
    for x in range(6):
        t1.forward(100) 
        t1.left(60)

def hex2():
    for x in range(6):
        t2.forward(100)
        t2.left(60) 

def hex3():
    for x in range(6):
        t3.forward(100)
        t3.left(60)
    
def hex4():
    for x in range(6):
        t4.forward(100)
        t4.left(60)
    
def hex5():
    for x in range(6):
        t5.forward(100)
        t5.left(60)
        
def move():
    t1.forward(10)
    t2.forward(10)
    t3.forward(10)
    t4.forward(10)
    t5.forward(10)
    t6.forward(10)  
    
    
def hex6():
    for x in range(6):
        t6.forward(100)
        t6.left(60)
        
        
def ghex():
        hex1()
        hex2()
        hex3()
        hex4()
        hex5()
        hex6()
        move()

def chaos():
    for x in range(2):
        ghex()

def shift
    for x in range():
        t2.color("grey")
        t2.setheading(120)
      
        
chaos()
